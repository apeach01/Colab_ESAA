# %% [markdown]
# <a href="https://colab.research.google.com/github/jackie-Gung/Colab_ESAA/blob/main/2022_03_25_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **04-1** 데이터 시각화가 필요한 이유
# ### * 앤스콤 함정 및 데이터 시각화 필요성
#   - **앤스콤 4분할 그래프 구성 데이터 집합:** 4개의 그룹으로 되어 있어 모든 데이터 그룹이 x, y열을 가짐
#   -  **함정:** **'데이터 그룹 a~d는 모두 같은 데이터이다'** -> 4개의 데이터 그룹 모두 평균과 분산 같은 수치값이나 상관관계, 회귀선 등이 같기 때문
#   -  **해결방법:** 각 데이터 그룹을 시각화하면 데이터 패턴이 다름을 알 수 있음
#   - 따라서 데이터 시각화는 데이터 분석 분야에서 아주 중요한 요소
#
# ### **1. 앤스콤 데이터 집합 불러온 후 그래프 그리기**
# #### 1) 앤스터 데이터 집합: seaborn 라이브러리에 포함되어 있음
#   - seaborn 라이브러리의 load_dataset 메서드에 문자열 anscombe을 전달 -> 앤스콤 데이터 집합을 불러옴
#   - dataset 열이 데이터 그룹을 구분함
#
# #### 2) matplotlib 라이브러리로 그래프 그리기
#   - 그래프 시각화를 위한 라이브러리
#
# #### 3) anscombe 데이터프레임의 datset 열에서 데이터 값이 I인 것만 추출하기
# #### 4) plot 매서드로 선 그래프를 그리기
#   - plot 메서드에 x,y축 데이터를 전달하면 선 그래프 나타남
#
# #### 5) 기본적으로 plot 메서드 통해 선으로 그래프 그리기
#   - 점: 세번째 인자로 'o'을 전달하면 됨

# %%
import numpy as np
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe.head(5))
print(type(anscombe))
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33
# <class 'pandas.core.frame.DataFrame'>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
dataset1 = anscombe[anscombe['dataset'] == 'I']
dataset1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(dataset1['x'], dataset1['y'])

# %%
plt.plot(dataset1['x'],dataset1['y'], 'o')
# Out:
# <div id='263cd1b3-4c6f-4db8-85a0-d1be1ce226ef'></div>

# %% [markdown]
# ### 2. 앤스콤 데이터 집합 모두 사용해 그래프 만들기
# #### 1) 앤스콤 데이터프레임의 dataset 열의 값이 I,II,III,IV인 것을 불린 추출하여 dataset_1,2,3,4에 저장하기
# #### 2) 먼저 그래프 격자가 위치할 기본 틀을 만들기
# #### 3) add_subplot 메서드로 그래프 격자를 그리기
#   - 첫번째 인자에 그래프 기본 틀의 행 크기
#   - 두번째 인자에 그래프 기본 틀의 열 크기
#
# #### 4) plot 메서드에 데이터를 전달하여 그래프 그리기
#   - 그래프 확인하려면 fig 반드시 입력할 것
#
# #### 5) 그래프를 각각 쉽게 구분할 수 있도록 그래프 격자에 제목을 추가하기
#   - set_title 메서드로 그래프 이름 전달함
#
# #### 6) 기본 틀(fig)에도 제목 추가하기
#   - suptitle 메서드 사용함
#
# #### 7) 겹치는 그래프의 이름과 숫자 조절하기
#   - fig.tight_layout() 메서드 호출

# %%
# 1
dataset2 = anscombe[anscombe['dataset'] == 'II']
dataset3 = anscombe[anscombe['dataset'] == 'III']
dataset4 = anscombe[anscombe['dataset'] == 'IV']

# %%
# 2
fig = plt.figure()
# Out:
# <div id='afeb2d6b-59cc-4256-b299-61566935871d'></div>

# %%
# 3
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
# 4
axes1.plot(dataset1['x'], dataset1['y'], 'o')
axes2.plot(dataset2['x'], dataset2['y'], 'o')
axes3.plot(dataset3['x'], dataset3['y'], 'o')
axes4.plot(dataset4['x'], dataset4['y'], 'o')
fig
# Out:
# <div id='3b8354c9-9f9c-41ac-9da1-c0ce21841785'></div>

# %%
# 5
axes1.set_title('dataset1')
axes2.set_title('dataset2')
axes3.set_title('dataset3')
axes4.set_title('dataset4')
fig
# Out:
# <div id='038c1db7-8d1a-4946-bd87-a1eb9c930969'></div>

# %%
fig.suptitle('Anscombe Data')
fig
# Out:
# <div id='d5837b13-b64f-4546-a96e-5ade53f5996c'></div>

# %%
fig.tight_layout()

# %% [markdown]
# ## **04-2 matplotlib 라이브러리 자유자재로 사용하기**
# ## **- 기초 그래프 그리기**
# ### 1. **기초 그래프 그리기: 히스토그램, 산점도, 박스**
# #### 1) tips 데이터 집합 불러와 새로운 변수에 저장
# #### 2) histogram: dataframe의 열 데이터 분포와 빈도를 살펴보는 용도로 사용됨
#   - 일변량 그래프: 변수 하나만 사용하여 그린 그래프
#
# #### 3) 기본 틀(fig)을 마련하고 그래프 격자(axest)를 구성하기 (전과 동일)
# #### 4) hist 메서드에 total_bill 전달하여 histogram 만들기
#   - x 간격: bins 인잣값으로 조정
#   - xlabel&ylabel: x,y축 제목
#   - title: 그래프 제목
#
# #### 5) 산점도 그래프 그려보기
#   - 변수 2개 사용하기 (이변량 그래프)
#
# #### 6) 산점도를 그리기 위한 기본 틀과 scatter 메서드 사용하기
# #### 7) 박스 그래프 그려보기
#   - 이산형+연속형 변수를 함께 사용
#
# #### 8) boxplot 메서드 사용하기
#   - 열 데이터를 추출하여 리스트에 담기
#   - 두 번째 인자에는 labels 인잣값

# %%
# 1
tips = sns.load_dataset('tips')
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
# 2-3
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)
# Out:
# <div id='7305472c-5e0f-4aa6-b9d5-303cbf005579'></div>

# %%
# 4
axes1.hist(tips['total_bill'], bins = 10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')
fig
# Out:
# <div id='60692dea-d055-43d8-aa9d-e5fb18b2cdcd'></div>

# %%
# 5-6
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['time'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <div id='e4218e3a-fc61-4257-b32e-a15ce628ff03'></div>
# Text(0, 0.5, 'Tip')

# %%
# 7-8
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
               tips[tips['sex'] == 'Male']['tip']],
              labels = ['Female', 'Male'])
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# <div id='5588209d-4a27-4a5a-9dab-6956c7140a7a'></div>
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ## **- 다변량 그래프 그리기**
#   - 다변량 그래프: 3개 이상의 변수를 사용한 그래프
#   - 적재적소에 맞는 그래프 요소를 추가하여 그래프를 표현하기 위해 다변량 그래프 필요함
#
# #### 1. 다변량 데이터로 다변량 그래프 그리기 - 산점도 그래프
# #### 1) 앞실습에서 한 그래프+성별 변수 추가하기
#   - 산점도 그래프에서 색상으로 구분하면 됨
#   - 문자열의 변수는 색상 지정값으로 사용할 수 없음
#   - 따라서 0,1과 같은 정수를 사용해야 함
#   - 예) 남자 = 1, 여자 = 0
#
# #### 2) recode_sex 메서드가 반환한 값을 dataframe에 추가하기
#   - recode_sex 메서드가 반환한 값을 새로운 열을 생성해 추가해야함
#   - 브로드캐스팅하기 위해 apply 메서드 사용함
#
# #### 3) 인원수 변수도 그래프에 추가하기
#   - 테이블 인원수는 점의 크기로 표현하면 됨
#   - scatter 메서드에 s,c 인잣값으로 테이블당 인원 수 및 성별의 치환값을 전달하면 됨

# %%
# 1
def recode_sex(sex) : 
  if sex == 'Female' :
    return 0
  else : 
    return 1

# %%
# 2
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
# 3
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x = tips['total_bill'],
    y = tips['tip'],
    s = tips['size']*10,
    c = tips['sex_color'],
    alpha = 0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <div id='6d3ec762-bad9-4c01-a568-897a9e00bcd2'></div>
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ## **04-3 seaborn 라이브러리 자유자재로 사용하기**
# ## - seaborn 라이브러리 자체를 활용
# ## - matplotlib보다 더 화려한 그래프 가능
# #### **1. 단변량 그래프 그리기- histogram**
# #### 1) seaborn -> sns
# #### 2) subplots, distplot 메서드 사용하기
#   - subplots: 기본 틀을 만들기
#   - displot: total_bill 열 데이터 전달
#
# #### 3) distplot: histogram & 밀집도 그래프도 함께 그리기
#   - 밀집도 제외: kde 인잣값 = False
#
# #### 4) 밀집도 그래프만 나타내기
#   - hist 인잣값 = False
#
# #### 5) 그래프 한 번에 출력하기
#   - displot + **rug**
#
# #### 6) count 그래프 그려보기
#   - 이산값을 나타낸 그래프
#   - countplot 메서드 + tips dataframe의 day 열 추가

# %%
# 1
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
# 2
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title("Total Bill Histogram with Density Plot")
# Out:
# <div id='4aa105e3-d795-40cb-b198-bdf7132f7507'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
# 3
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde = False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <div id='f81875a3-3347-4d69-96cc-bc4ec7fc1823'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
# 4
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist = False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# <div id='62747a8f-0093-4a98-90bd-957097f9fc79'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Unit Probability')

# %%
# 5
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug = True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# <div id='0380c34b-1d70-42f7-9ad6-64b2255d13e6'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Total Bill')

# %%
# 6
ax = plt.subplots()
ax = sns.countplot('day', data = tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# <div id='9377344a-4689-4f6f-8ee9-b8db0f8646cd'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# #### 2. 다양한 종류의 이변량 그래프 그리기
# #### 1) seaborn 라이브러리 산점도 그래프 그리기
#   - seaborn 라이브러리는 matplotlib 라이브러리보다 다양한 방법으로 산점도 그래프를 그릴 수 있음
#   - 산점도 그래프를 그리려면 seaborn library의 regplot 메서드를 사용해야함
#   - 산점도 그래프+ 회귀선을 함께 그릴 수 있음
#   - 회귀선 제거: fit_reg = False
#
# #### 2) 산점도와 histogram을 한 번에 그리기
#   - jointplot: x,y이낮에 원하는 열 지정
#   - data 인잣값으로 dataframe 지정
#
# #### 3) 산점도 그래프 단점
#   - 점이 겹쳐 보일 때 구분하기 어려움
#   - 방지하기 위해 hexbin(육각 그래프) 사용
#   - 육각그래프: 2차원 표면에 육각형 데이터를 쌓아 표현하는 그래프
#   - 특정 데이터 개수 많아지면 점이 진해짐
#   - jointplot 그대로 사용 + kind = hex
#
# #### 4) 이차원 밀집도 그리기
#   - kdeplot 메서드
#   - shade = True: 그래프 음영 효과
#
# #### 5) 바 그래프 그리기
#   - 지정한 변수의 평균을 계산할 수 있음
#   - 시간에 따라 지불한 비용의 평균 나타냄(아래 코드)
#
# #### 6) 박스 그래프 그리기
#   - 최소값, 1분위수, 중간값, 3분위수, 최대값, 이상치 등 다양한 통계량을 한 번에 표현하는 그래프
#   - 통계 수치 확인을 위해 자주 쓰임
#   - 데이터 분산이 모호하게 표현됨 -> 커널 밀도를 추정한 바이올린 그래프 사용하면 됨 -> violinplot 메서드 사용
#
# #### 7) 관계 그래프 그리기
#   - 위에서 언급한 모든 그래프를 종합한 그래프
#   - pairplot 사용함
#   - 중복된 정보가 표현될 수 있는 단점
#   - 관계 그래프의 절반은 나머지 절반과 같음
#   - 해결: 중복된 그래프가 그려지는 위치를 직접 지정하여 원하는 그래프로 교체함
#   - map_upper: 대각선을 기준으로 위쪽에 그릴 그래프 지정
#   - map_lower: 대각선을 기준으로 아래쪽에 그릴 그래프 지정
#   - map_diag: 대각선 중심으로 그래프 그리기

# %%
# 1
ax = plt.subplots()
ax = sns.regplot(x= 'total_bill', y = 'tip', data = tips)
ax.set_title('Scatterplot of Total Bill and Trip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

ax = plt.subplots()
ax = sns.regplot(x= 'total_bill', y = 'tip', data = tips, fit_reg = False)
ax.set_title('Scatterplot of Total Bill and Trip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <div id='7f1721b1-9d35-4377-b875-69beeaa9dc38'></div>
# <div id='e5c361a1-0ce2-4504-962a-c32e80299b92'></div>
# Text(0, 0.5, 'Tip')

# %%
# 2
joint = sns.jointplot(x = 'total_bill', y = 'tip', data = tips)
joint.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize = 10, y = 1.03)
# Out:
# <div id='0f86e35d-3e4d-43ed-bcc7-78371c7b243c'></div>
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
# 3
hexbin = sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'hex')
hexbin.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize = 10, y =1.03)
# Out:
# <div id='590e6b67-f9a3-4c05-a60b-d7c6c83423ed'></div>
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %%
# 4
ax = plt.subplots()
ax = sns.kdeplot(data = tips['total_bill'],
                 data2 = tips['tip'],
                 shade = True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <div id='37ff9d95-68b4-46f7-9bed-495a5c47a964'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1681: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Tip')

# %%
# 5
ax = plt.subplots()
ax = sns.barplot(x = 'time', y = 'total_bill', data = tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# <div id='63ccbb50-0de7-4bbc-aab5-9a285f49dd96'></div>
# Text(0, 0.5, 'Average total bill')

# %%
# 6
ax = plt.subplots()
ax = sns.boxplot(x = 'time', y = 'total_bill', data = tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# <div id='227dd473-d695-417b-ac1e-e3f035e23023'></div>
# Text(0, 0.5, 'Total Bill')

# %%
# 7
ax = plt.subplots()
ax = sns.violinplot(x = 'time', y = 'total_bill', data = tips)
ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# <div id='c6a33ddc-9404-4cdb-8147-b171841828ee'></div>
# Text(0, 0.5, 'Total Bill')

# %%
# 8
fig = sns.pairplot(tips)
# Out:
# <div id='adf5c3ad-b05a-4216-a7d8-5d52e4a6a8db'></div>

# %%
# 9
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug = True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1242: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='d9fa676c-e9df-43c1-a9b9-92c57a29dc78'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
# ...

# %% [markdown]
# #### 3. 다변량 그래프 그리기 - with seaborn
# #### 1) seaborn 라이브러리로 바이올린 그래프 그리기
#   - 바이올린 그래프에 색상 추가
#   - violin 메서드에서 hue 인잣값으로 색상에 사용할 열 이름을 추가
#
# #### 2) 산점도, 관계 그래프 그리기
#   - 색상 추가
#
# #### 3) 산점도 그래프의 크기 및 모양 조절하기
#   - 점 크기 조절: scatter_kws에 **딕셔너리** 형태로 인잣값 전달하면 됨
#   - 크기만 조절: 's' : tips['size'] 딕셔너리에 전달
#
# #### 4) 그래프 점을 다른 기호로 표현하기
#   - markers: 인잣값에 표현하고자 하는 기호를 **리스트**에 담아 전달
#
# #### 5) implot 메서드로 4개 데이터 그룹에 대한 그래프를 한 번에 그리기
#   - implot 메서드에 **col, col_wrap** 인자를 추가로 설정해야함
#   - col_wrap 인자에는 그래프를 그릴 **열의 최대값**을 지정
#   - col 인자에는 데이터 그룹을 구분할 열을 지정

# %%
# 1
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue = 'sex', data=tips, split = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <div id='8a249d4c-c80d-4439-8c7b-86778c42d26c'></div>

# %%
# 2
scatter = sns.lmplot(x = 'total_bill', y = 'tip', data= tips, hue = 'sex', fit_reg = False)
fig = sns.pairplot(tips, hue = 'sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='8a735635-b329-4031-a3a6-2551667eb09f'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1242: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='c7fbda4e-f6a8-4f6a-9d1c-164572ceabb4'></div>

# %%
# 3
scatter = sns.lmplot(x = 'total_bill', y ='tip', data = tips, fit_reg = False, hue = 'sex', scatter_kws = {'s' : tips['size']*10})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='dc152202-9b0c-4a4b-8f55-99699f957da6'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-f49394af2adb> in <module>()
#       1 # 3
# ----> 2 scatter = sns.lmplot(x = 'total_bill', y ='tip', data = tips, fit_reg = False, hue = 'sex', scatter_kws = {'s' : tips['size']*10})
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ...

# %%
# 4
scatter = sns.lmplot(x = 'total_bill', y = 'tip', data = tips, fit_reg = False,
                     hue = 'sex', markers = ['o', 'x'], 
                     scatter_kws = {'s' : tips['size']*10})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='70e8798b-2589-4fb8-b715-66833bcb663f'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-3ca36b38dd20> in <module>()
#       2 scatter = sns.lmplot(x = 'total_bill', y = 'tip', data = tips, fit_reg = False,
#       3                      hue = 'sex', markers = ['o', 'x'],
# ----> 4                      scatter_kws = {'s' : tips['size']*10})
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
# ...

# %%
# 5,6
anscombe_plot = sns.lmplot(x = 'x', y = 'y', data = anscombe, fit_reg = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='a8149a84-15eb-4e7b-be2d-0e5a5a0016c5'></div>

# %% [markdown]
# ## 04-4 DataFrame과 시리즈로 그래프 그리기
# ### 1. 데이터프래임과 시리즈 사용
# #### 1) Histogram 그리기
# #### 2) 투명도 조절
#   - hist 메서드에 **alpha, bins, ax** 인자 사용
#
# #### 3) 밀집도, 산점도, 육각 그래프
#   - kde / scatter / hexbin 메서드 사용
#
# #### 4) 육각 그래프의 육각형 크기 변경하기
#   - gridsize 인자 사용함
#
# #### 5) 박스 그래프 만들기
#   - box 메서드 사용함

# %%
# 1
ax = plt.subplots()
ax = tips['total_bill'].plot.hist()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <div id='5af275d2-2c82-46d7-bae2-1c1b1ad365b5'></div>

# %%
# 2
fig, ax = plt.subplots()
ax = tips[['total_bill', 'tip']].plot.hist(alhpa = 0.5, bins = 20, ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <div id='741c3a12-45be-4dfe-872f-4bd4bcc166a2'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-ce671c378eda> in <module>()
#       1 # 2
#       2 fig, ax = plt.subplots()
# ----> 3 ax = tips[['total_bill', 'tip']].plot.hist(alhpa = 0.5, bins = 20, ax = ax)
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwargs)
#    1311             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1312         """
# -> 1313         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1314
# ...

# %%
# 3
## kde: 밀집도
ax = plt.subplots()
ax = tips['tip'].plot.kde()

## scatter: 산점도 그래프
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill', y = 'tip', ax = ax)

## hexbin: 육각 그래프
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x = 'total_bill', y = 'tip', ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# <div id='bfeee974-0315-4e69-908a-ea018f49b634'></div>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys
# <div id='1d75a965-b3c0-4ecd-a70f-ae8bdd5442f1'></div>
# ...

# %%
# 4
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x = 'total_bill', y = 'tip', gridsize = 10, ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <div id='c41e60cb-0292-470c-9f77-edbc87985bf7'></div>

# %%
# 5
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <div id='2f7e5689-1a21-45c0-a7ca-37c34e00d13a'></div>
